# %%
print('hello')
# Out:
# hello

# %%
import os
from random import choice
import shutil

#arrays to store file names
imgs =[]
xmls =[]

#setup dir names
trainPath = '/Users/habib/Study/366 Project/Working/dataset/images/train'
valPath = '/Users/habib/Study/366 Project/Working/dataset/images/val'
testPath = '/Users/habib/Study/366 Project/Working/dataset/images/test'
crsPath = '/Users/habib/Study/366 Project/Working/beedata/images' #dir where images and annotations stored

#setup ratio (val ratio = rest of the files in origin dir after splitting into train and test)
train_ratio = 0.7
val_ratio = 0.2
test_ratio = 0.1


#total count of imgs
totalImgCount = len(os.listdir(crsPath))/2

#soring files to corresponding arrays
for (dirname, dirs, files) in os.walk(crsPath):
    for filename in files:
        if filename.endswith('.txt'):
            xmls.append(filename)
        else:
            imgs.append(filename)


#counting range for cycles
countForTrain = int(len(imgs)*train_ratio)
countForVal = int(len(imgs)*val_ratio)
countForTest = int(len(imgs)*test_ratio)
print("training images are : ",countForTrain)
print("Validation images are : ",countForVal)
print("Test images are : ",countForTest)
# Out:
# training images are :  438
# Validation images are :  125
# Test images are :  62

# %%
trainimagePath = '/Users/habib/Study/366 Project/Working/dataset/images/train'
trainlabelPath = '/Users/habib/Study/366 Project/Working/dataset/labels/train'
valimagePath = '/Users/habib/Study/366 Project/Working/dataset/images/val'
vallabelPath = '/Users/habib/Study/366 Project/Working/dataset/labels/val'
testimagePath = '/Users/habib/Study/366 Project/Working/dataset/images/test'
testlabelPath = '/Users/habib/Study/366 Project/Working/dataset/labels/test'
#cycle for train dir
# for x in range(countForTrain):

#     fileJpg = choice(imgs) # get name of random image from origin dir
#     fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

#     #move both files into train dir
#     #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
#     #shutil.move(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))
#     shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(trainimagePath, fileJpg))
#     shutil.copy(os.path.join(crsPath, fileXml), os.path.join(trainlabelPath, fileXml))


#     #remove files from arrays
#     imgs.remove(fileJpg)
#     xmls.remove(fileXml)



# cycle for val dir   
# for x in range(countForVal):

#     fileJpg = choice(imgs) # get name of random image from origin dir
#     fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

#     #move both files into train dir
#     #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
#     #shutil.move(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))
#     shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
#     shutil.copy(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))
    
#     #remove files from arrays
#     imgs.remove(fileJpg)
#     xmls.remove(fileXml)



    # cycle for test dir   
for x in range(countForTest):

    fileJpg = choice(imgs) # get name of random image from origin dir
    fileXml = fileJpg[:-4] +'.txt' # get name of corresponding annotation file

    #move both files into train dir
    #shutil.move(os.path.join(crsPath, fileJpg), os.path.join(valimagePath, fileJpg))
    #shutil.move(os.path.join(crsPath, fileXml), os.path.join(vallabelPath, fileXml))
    shutil.copy(os.path.join(crsPath, fileJpg), os.path.join(testimagePath, fileJpg))
    shutil.copy(os.path.join(crsPath, fileXml), os.path.join(testlabelPath, fileXml))
    
    #remove files from arrays
    imgs.remove(fileJpg)
    xmls.remove(fileXml)

# rest of files will be validation files, so rename origin dir to val dir
# os.rename(crsPath, valPath)
# shutil.move(crsPath, valPath)

# %%
# %pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.6/613.6 kB 2.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.6/29.6 MB 3.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 2.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 2.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 2.5 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.3/169.3 kB 2.7 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 3.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 3.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 MB 2.6 MB/s eta 0:00:0000:0100:01
# ...

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO()

# Train the model using the 'coco128.yaml' dataset for 3 epochs
results = model.train(data='/Users/habib/Study/366 Project/Working/dataset/data.yaml', epochs=10)
# Out:
# Ultralytics YOLOv8.0.169 🚀 Python-3.10.6 torch-2.0.1 CPU (Apple M1)
# ...

# %%
from ultralytics import YOLO
model = YOLO('/opt/homebrew/runs/detect/train4/weights/best.pt')  # load a custom model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.169 🚀 Python-3.10.6 torch-2.0.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
# val: Scanning /Users/habib/Study/366 Project/Working/dataset/labels/val.cache... 405 images, 4 backgrounds, 0 corrupt: 100%|██████████| 409/409 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:46<00:00,  1.77s/it]
#                    all        409       2332      0.966      0.865      0.948      0.673
# Speed: 0.4ms preprocess, 95.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /opt/homebrew/runs/detect/val
# array([    0.67261])

# %%
from ultralytics import YOLO
# !yolo task=detect mode=predict model='/opt/homebrew/runs/detect/train4/weights/best.pt' conf=0.25 source='/Users/habib/Study/366 Project/Working/dataset/images/test'
# Out:
# Ultralytics YOLOv8.0.169 🚀 Python-3.10.6 torch-2.0.1 CPU (Apple M1)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients
#
# image 1/150 /Users/habib/Study/366 Project/Working/dataset/images/test/20230609a1026.jpg: 384x640 3 class_0s, 45.5ms
# image 2/150 /Users/habib/Study/366 Project/Working/dataset/images/test/20230609a1032.jpg: 384x640 3 class_0s, 47.8ms
# image 3/150 /Users/habib/Study/366 Project/Working/dataset/images/test/20230609a1068.jpg: 384x640 3 class_0s, 42.6ms
# image 4/150 /Users/habib/Study/366 Project/Working/dataset/images/test/20230609a1080.jpg: 384x640 4 class_0s, 41.3ms
# image 5/150 /Users/habib/Study/366 Project/Working/dataset/images/test/20230609a1254.jpg: 384x640 5 class_0s, 47.6ms
# image 6/150 /Users/habib/Study/366 Project/Working/dataset/images/test/20230609a1428.jpg: 384x640 2 class_0s, 43.3ms
# image 7/150 /Users/habib/Study/366 Project/Working/dataset/images/test/20230609a144.jpg: 384x640 6 class_0s, 47.5ms
# ...
